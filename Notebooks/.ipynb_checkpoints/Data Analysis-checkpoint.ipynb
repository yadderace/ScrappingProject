# %% [markdown]
# # Data Wrangling and Visualization

# %% [markdown]
# ## Librerias
#
# ### Instalacion

# %% [markdown]
# ### Importacion

# %%
import pandas as pd

# %% [markdown]
# ## Lectura Datos

# %%
dfFinalSet = pd.read_csv('FinalSet.csv', dtype = {'codigoencabezado': 'int32'})

dfFinalSet.describe(include = 'all')
# Out:
#         codigoencabezado    idregistro  \
# count         520.000000  5.200000e+02
# unique               NaN           NaN
# top                  NaN           NaN
# freq                 NaN           NaN
# mean          260.500000  1.092811e+09
# std           150.255338  1.723419e+07
# min             1.000000  1.033663e+09
# 25%           130.750000  1.100198e+09
# 50%           260.500000  1.100371e+09
# 75%           390.250000  1.100374e+09
# max           520.000000  1.100380e+09
#
#                                                linkpagina fecharegistro  \
# count                                                 520           520
# unique                                                303             4
# top     https://www.olx.com.gt/item/vendo-en-zona-10-a...    2020-05-20
# freq                                                    5           240
# mean                                                  NaN           NaN
# ...

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Conversion Series

# %%
dfFinalSet = dfFinalSet.astype({'codigoencabezado': 'str', 
                                'idregistro': 'str',
                                'partner_code': 'str',
                                'user_id': 'str'
                               })

dfFinalSet['fecharegistro'] = pd.to_datetime(dfFinalSet['fecharegistro'], format = "%Y-%m-%d")

dfFinalSet.describe(include = 'all')
# Out:
#        codigoencabezado  idregistro  \
# count               520         520
# unique              520         303
# top                 159  1100373436
# freq                  1           5
# first               NaN         NaN
# last                NaN         NaN
# mean                NaN         NaN
# std                 NaN         NaN
# min                 NaN         NaN
# 25%                 NaN         NaN
# 50%                 NaN         NaN
# 75%                 NaN         NaN
# max                 NaN         NaN
#
#                                                linkpagina  \
# count                                                 520
# unique                                                303
# top     https://www.olx.com.gt/item/vendo-en-zona-10-a...
# freq                                                    5
# first                                                 NaN
# last                                                  NaN
# ...

# %% [markdown]
# ### Registros Unicos
# Se obtendran solo los ultimos registros obtenidos para cada id de registro (idregistro)

# %%
dfAnalisisSet = dfFinalSet.loc[dfFinalSet.reset_index().groupby(['idregistro'])['fecharegistro'].idxmax()]

dfAnalisisSet
# Out:
#     codigoencabezado  idregistro  \
# 323              324  1033662607
# 425              426  1044844084
# 426              427  1044844541
# 427              428  1044963404
# 428              429  1045112739
# ..               ...         ...
# 308              309  1100379608
# 307              308  1100379612
# 306              307  1100379641
# 305              306  1100379667
# 304              305  1100379688
#
#                                             linkpagina fecharegistro  \
# 323  https://www.olx.com.gt/item/se-alquila-apartam...    2020-05-20
# 425  https://www.olx.com.gt/item/apartamento-en-zon...    2020-05-20
# 426  https://www.olx.com.gt/item/apartamento-en-lir...    2020-05-20
# 427  https://www.olx.com.gt/item/apartamento-en-lir...    2020-05-20
# 428  https://www.olx.com.gt/item/apartamento-torre-...    2020-05-20
# ..                                                 ...           ...
# 308  https://www.olx.com.gt/item/bonito-apartamento...    2020-05-20
# ...
