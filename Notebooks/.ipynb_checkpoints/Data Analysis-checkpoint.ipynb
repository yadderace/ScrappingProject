# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Librerias
#
# ### Instalacion

# %%
import sys
# !{sys.executable} -m pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.10.1-py3-none-any.whl (215 kB)
# Collecting matplotlib>=2.1.2
#   Downloading matplotlib-3.2.1-cp37-cp37m-win_amd64.whl (9.2 MB)
# Requirement already satisfied: pandas>=0.22.0 in c:\users\yadde\miniconda3\lib\site-packages (from seaborn) (1.0.3)
# Collecting scipy>=1.0.1
#   Downloading scipy-1.4.1-cp37-cp37m-win_amd64.whl (30.9 MB)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\yadde\miniconda3\lib\site-packages (from seaborn) (1.18.4)
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\yadde\miniconda3\lib\site-packages (from matplotlib>=2.1.2->seaborn) (2.8.1)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.2.0-cp37-none-win_amd64.whl (57 kB)
# Requirement already satisfied: pytz>=2017.2 in c:\users\yadde\miniconda3\lib\site-packages (from pandas>=0.22.0->seaborn) (2020.1)
# Requirement already satisfied: six in c:\users\yadde\miniconda3\lib\site-packages (from cycler>=0.10->matplotlib>=2.1.2->seaborn) (1.14.0)
# Installing collected packages: pyparsing, cycler, kiwisolver, matplotlib, scipy, seaborn
# Successfully installed cycler-0.10.0 kiwisolver-1.2.0 matplotlib-3.2.1 pyparsing-2.4.7 scipy-1.4.1 seaborn-0.10.1

# %% [markdown]
# ### Importacion

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %% [markdown]
# ## Lectura Datos

# %%
dfFinalSet = pd.read_csv('FinalSet.csv', dtype = {'codigoencabezado': 'int32'})

dfFinalSet.describe(include = 'all')
# Out:
#         codigoencabezado    idregistro  \
# count         520.000000  5.200000e+02
# unique               NaN           NaN
# top                  NaN           NaN
# freq                 NaN           NaN
# mean          260.500000  1.092811e+09
# std           150.255338  1.723419e+07
# min             1.000000  1.033663e+09
# 25%           130.750000  1.100198e+09
# 50%           260.500000  1.100371e+09
# 75%           390.250000  1.100374e+09
# max           520.000000  1.100380e+09
#
#                                                linkpagina fecharegistro  \
# count                                                 520           520
# unique                                                303             4
# top     https://www.olx.com.gt/item/alquilo-apartament...    2020-05-20
# freq                                                    5           240
# mean                                                  NaN           NaN
# std                                                   NaN           NaN
# min                                                   NaN           NaN
# 25%                                                   NaN           NaN
# 50%                                                   NaN           NaN
# 75%                                                   NaN           NaN
# max                                                   NaN           NaN
#
#         administracion amueblado  antiguedad       banos  habitaciones  \
# count        97.000000       295         178  520.000000    520.000000
# unique             NaN         2           7         NaN           NaN
# top                NaN        No  A estrenar         NaN           NaN
# freq               NaN       216          56         NaN           NaN
# mean        434.608247       NaN         NaN    1.988462      2.155769
# std         692.991501       NaN         NaN    0.851080      0.853851
# min           0.000000       NaN         NaN    1.000000      1.000000
# 25%           0.000000       NaN         NaN    1.000000      2.000000
# 50%           0.000000       NaN         NaN    2.000000      2.000000
# 75%         750.000000       NaN         NaN    2.000000      3.000000
# max        2000.000000       NaN         NaN    5.000000      8.000000
#
#        estudio  ...  moneda         tipo  tipo_vendedor   favoritos  \
# count      520  ...     520          520            431  520.000000
# unique       2  ...       2            2              2         NaN
# top         No  ...     US$  Apartamento   Inmobiliaria         NaN
# freq       515  ...     377          511            385         NaN
# mean       NaN  ...     NaN          NaN            NaN    1.355769
# std        NaN  ...     NaN          NaN            NaN    3.213406
# min        NaN  ...     NaN          NaN            NaN    0.000000
# 25%        NaN  ...     NaN          NaN            NaN    0.000000
# 50%        NaN  ...     NaN          NaN            NaN    0.000000
# 75%        NaN  ...     NaN          NaN            NaN    1.000000
# max        NaN  ...     NaN          NaN            NaN   33.000000
#
#                                 titulo             fecha_creacion  \
# count                              520                        520
# unique                             292                        323
# top     APARTAMENTO EN ZONA 15 / ACODI  2020-05-16T03:21:04-06:00
# freq                                 7                          8
# mean                               NaN                        NaN
# std                                NaN                        NaN
# min                                NaN                        NaN
# 25%                                NaN                        NaN
# 50%                                NaN                        NaN
# 75%                                NaN                        NaN
# max                                NaN                        NaN
#
#                      valido_hasta  \
# count                         520
# unique                        299
# top     2020-08-13T03:22:20-06:00
# freq                            8
# mean                          NaN
# std                           NaN
# min                           NaN
# 25%                           NaN
# 50%                           NaN
# 75%                           NaN
# max                           NaN
#
#                                               descripcion partner_code  \
# count                                                 520           81
# unique                                                300           47
# top     Vivienda abierta (sin muros en el dormitorio),...        11218
# freq                                                    6            4
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#              user_id
# count   5.200000e+02
# unique           NaN
# top              NaN
# freq             NaN
# mean    3.356498e+07
# std     2.283419e+07
# min     4.263970e+06
# 25%     2.325799e+07
# 50%     2.678192e+07
# 75%     5.658755e+07
# max     8.030986e+07
#
# [11 rows x 26 columns]

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Conversion Series

# %%
dfAnalisisSet = dfFinalSet.astype({'codigoencabezado': 'str', 
                                'idregistro': 'str',
                                'partner_code': 'str',
                                'user_id': 'str'
                               })

dfAnalisisSet['fecharegistro'] = pd.to_datetime(dfAnalisisSet['fecharegistro'], format = "%Y-%m-%d")

dfAnalisisSet.describe(include = 'all')
# Out:
#        codigoencabezado  idregistro  \
# count               520         520
# unique              520         303
# top                 349  1100373467
# freq                  1           5
# first               NaN         NaN
# last                NaN         NaN
# mean                NaN         NaN
# std                 NaN         NaN
# min                 NaN         NaN
# 25%                 NaN         NaN
# 50%                 NaN         NaN
# 75%                 NaN         NaN
# max                 NaN         NaN
#
#                                                linkpagina  \
# count                                                 520
# unique                                                303
# top     https://www.olx.com.gt/item/alquilo-apartament...
# freq                                                    5
# first                                                 NaN
# last                                                  NaN
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#               fecharegistro  administracion amueblado  antiguedad       banos  \
# count                   520       97.000000       295         178  520.000000
# unique                    4             NaN         2           7         NaN
# top     2020-05-20 00:00:00             NaN        No  A estrenar         NaN
# freq                    240             NaN       216          56         NaN
# first   2020-05-14 00:00:00             NaN       NaN         NaN         NaN
# last    2020-05-20 00:00:00             NaN       NaN         NaN         NaN
# mean                    NaN      434.608247       NaN         NaN    1.988462
# std                     NaN      692.991501       NaN         NaN    0.851080
# min                     NaN        0.000000       NaN         NaN    1.000000
# 25%                     NaN        0.000000       NaN         NaN    1.000000
# 50%                     NaN        0.000000       NaN         NaN    2.000000
# 75%                     NaN      750.000000       NaN         NaN    2.000000
# max                     NaN     2000.000000       NaN         NaN    5.000000
#
#         habitaciones estudio  ...  moneda         tipo  tipo_vendedor  \
# count     520.000000     520  ...     520          520            431
# unique           NaN       2  ...       2            2              2
# top              NaN      No  ...     US$  Apartamento   Inmobiliaria
# freq             NaN     515  ...     377          511            385
# first            NaN     NaN  ...     NaN          NaN            NaN
# last             NaN     NaN  ...     NaN          NaN            NaN
# mean        2.155769     NaN  ...     NaN          NaN            NaN
# std         0.853851     NaN  ...     NaN          NaN            NaN
# min         1.000000     NaN  ...     NaN          NaN            NaN
# 25%         2.000000     NaN  ...     NaN          NaN            NaN
# 50%         2.000000     NaN  ...     NaN          NaN            NaN
# 75%         3.000000     NaN  ...     NaN          NaN            NaN
# max         8.000000     NaN  ...     NaN          NaN            NaN
#
#          favoritos                          titulo             fecha_creacion  \
# count   520.000000                             520                        520
# unique         NaN                             292                        323
# top            NaN  APARTAMENTO EN ZONA 15 / ACODI  2020-05-16T03:21:04-06:00
# freq           NaN                               7                          8
# first          NaN                             NaN                        NaN
# last           NaN                             NaN                        NaN
# mean      1.355769                             NaN                        NaN
# std       3.213406                             NaN                        NaN
# min       0.000000                             NaN                        NaN
# 25%       0.000000                             NaN                        NaN
# 50%       0.000000                             NaN                        NaN
# 75%       1.000000                             NaN                        NaN
# max      33.000000                             NaN                        NaN
#
#                      valido_hasta  \
# count                         520
# unique                        299
# top     2020-08-13T03:22:20-06:00
# freq                            8
# first                         NaN
# last                          NaN
# mean                          NaN
# std                           NaN
# min                           NaN
# 25%                           NaN
# 50%                           NaN
# 75%                           NaN
# max                           NaN
#
#                                               descripcion partner_code  \
# count                                                 520          520
# unique                                                300           48
# top     Vivienda abierta (sin muros en el dormitorio),...          nan
# freq                                                    6          439
# first                                                 NaN          NaN
# last                                                  NaN          NaN
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#          user_id
# count        520
# unique        91
# top     24012106
# freq          93
# first        NaN
# last         NaN
# mean         NaN
# std          NaN
# min          NaN
# 25%          NaN
# 50%          NaN
# 75%          NaN
# max          NaN
#
# [13 rows x 26 columns]

# %% [markdown]
# ### Registros Unicos
# Se obtendran solo los ultimos registros obtenidos para cada id de registro (idregistro) utilizando el campo fecharegistro.

# %%
dfAnalisisSet = dfAnalisisSet.loc[dfAnalisisSet.reset_index().groupby(['idregistro'])['fecharegistro'].idxmax()]

dfAnalisisSet.head(10)
# Out:
#     codigoencabezado  idregistro  \
# 323              324  1033662607
# 425              426  1044844084
# 426              427  1044844541
# 427              428  1044963404
# 428              429  1045112739
# 429              430  1045114174
# 430              431  1045221839
# 431              432  1045223186
# 471              472  1045634091
# 484              485  1047819336
#
#                                             linkpagina fecharegistro  \
# 323  https://www.olx.com.gt/item/se-alquila-apartam...    2020-05-20
# 425  https://www.olx.com.gt/item/apartamento-en-zon...    2020-05-20
# 426  https://www.olx.com.gt/item/apartamento-en-lir...    2020-05-20
# 427  https://www.olx.com.gt/item/apartamento-en-lir...    2020-05-20
# 428  https://www.olx.com.gt/item/apartamento-torre-...    2020-05-20
# 429  https://www.olx.com.gt/item/apartamento-liv-vi...    2020-05-20
# 430  https://www.olx.com.gt/item/apartamento-torre-...    2020-05-20
# 431  https://www.olx.com.gt/item/apartamento-en-cas...    2020-05-20
# 471  https://www.olx.com.gt/item/apartamentos-en-bo...    2020-05-20
# 484  https://www.olx.com.gt/item/apartamentos-en-sh...    2020-05-20
#
#      administracion amueblado antiguedad  banos  habitaciones estudio  ...  \
# 323             NaN        No        NaN      3             3      No  ...
# 425             NaN        No        NaN      1             1      No  ...
# 426             NaN       NaN        NaN      2             3      No  ...
# 427             NaN        No        NaN      2             3      No  ...
# 428             NaN       NaN        NaN      2             2      No  ...
# 429             NaN       NaN        NaN      2             3      No  ...
# 430             NaN       NaN        NaN      4             4      No  ...
# 431             NaN       NaN        NaN      2             3      No  ...
# 471             NaN       NaN        NaN      2             3      No  ...
# 484             NaN       NaN        NaN      1             1      No  ...
#
#      moneda         tipo  tipo_vendedor favoritos  \
# 323     US$  Apartamento   Inmobiliaria         1
# 425     US$  Apartamento   Inmobiliaria         0
# 426     US$  Apartamento   Inmobiliaria         0
# 427     US$  Apartamento   Inmobiliaria         0
# 428     US$  Apartamento   Inmobiliaria         1
# 429     US$  Apartamento   Inmobiliaria         0
# 430     US$  Apartamento   Inmobiliaria         1
# 431     US$  Apartamento   Inmobiliaria         1
# 471       Q  Apartamento   Inmobiliaria         2
# 484     US$  Apartamento   Inmobiliaria         1
#
#                                                 titulo  \
# 323  Se alquila Apartamento en zona 16 en el sector...
# 425                     APARTAMENTO EN ZONA 10 / ACODI
# 426             APARTAMENTO EN LIRIOS, ZONA 16 / ACODI
# 427             APARTAMENTO EN LIRIOS, ZONA 16 / ACODI
# 428  APARTAMENTO TORRE CAPRESE, ZONA 15 OPCIÓN 3/ACODI
# 429  APARTAMENTO LIV VISTA HERMOSA I, ZONA 15 OPCIÓ...
# 430  APARTAMENTO TORRE CAPRESE, ZONA 15 OPCIÓN 1/ A...
# 431      APARTAMENTO EN CASA MARGARITA, ZONA 10/ ACODI
# 323  Apartamento para estrenar muy cerca a Cayalá, ...          nan  15462053
# 425  Edificio\n– Piscina\n– Gimnasio\n– Área verde ...          nan  24012106
# 426  – Área de construcción: 120 m2\n\n– Sala\n– Co...          nan  24012106
# 427  Edificio\n– Piscina\n– Gimnasio\n– Áreas verde...          nan  24012106
# 428  Edificio\n– De 11 Niveles\n– 2 Elevadores\n– 2...          nan  24012106
# 429  Complejo \n– Accesos por 2 vías (19 avenida y ...          nan  24012106
# 430  Edificio\n– De 11 Niveles\n– 2 Elevadores\n– 2...          nan  24012106
# 431  Edificio\n– Piscina\n– Gimnasio\n– Sauna\n– Sa...          nan  24012106
# 471  Edificio:\n– Garita de control\n– Salón social...          nan  24012106
# 484  Edificio\n– Lobby\n– Gimnasio\n– Lounge\n– Spa...          nan  24012106
#
#      precio_real
# 323     23070.00
# 425      7690.00
# 426   2022470.00
# 427      9997.00
# 428   2679072.96
# 429   3187843.36
# 430   7533893.00
# 431   6921000.00
# 471   1041468.00
# 484    943301.54
#
# [10 rows x 27 columns]

# %% [markdown]
# ### Columna Oferta
# Se creara una columna que determine si la oferta es de alquiler o venta. Se utilizara el campo

# %%
dfAnalisisSet['oferta'] = ['Venta' if precio > 20000 else 'Alquiler' for precio in dfAnalisisSet['precio']]

dfAnalisisSet.groupby(['oferta']).count()['codigoencabezado']
# Out:
# oferta
# Alquiler    183
# Venta       120
# Name: codigoencabezado, dtype: int64

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Precio por apartamento amueblado

# %%
sns.catplot(x = 'amueblado', y = 'precio', 
            col = 'oferta', 
            kind = 'box', 
            data = dfAnalisisSet,
            palette = 'GnBu_d',
            height=4, 
            aspect=.7)

# %% [markdown]
# ### Precio por antiguedad

# %%
# Obteniendo los diferentes subsets, para venta y alquiler.
dfTemp1 = dfAnalisisSet.loc[dfAnalisisSet['oferta'] == 'Alquiler', ['precio', 'antiguedad']]
dfTemp1['antiguedad'] = dfTemp1['antiguedad'].astype('category')

dfTemp2 = dfAnalisisSet.loc[dfAnalisisSet['oferta'] == 'Venta', ['precio', 'antiguedad']]
dfTemp2['antiguedad'] = dfTemp2['antiguedad'].astype('category')


# Definiendo el lienzo como subplots de 2 filas y 1 columna
fig, ax = plt.subplots(2, 1)

# Definiendo tamano
fig.set_figheight(10)
fig.set_figwidth(10)

# Generando la primera grafica (Alquiler)
g1 = sns.boxplot(y='precio', x='antiguedad', data=dfTemp1, ax=ax[0], palette = 'GnBu_d')
#g1.set(xticklabels=[])
g1.set(title='Precio por antiguedad de la casa (Alquiler)')
g1.set(xlabel=None)

# Generando la segunda grafica (Venta)
g2 = sns.boxplot(y='precio', x='antiguedad', data=dfTemp2, ax=ax[1], palette = 'Blues')
#g2.set(xticklabels=[])
g2.set(title='Precio por antiguedad de la casa (Venta)')
#g2.set(xlabel=None)

# Se muestra la grafica
plt.show()
